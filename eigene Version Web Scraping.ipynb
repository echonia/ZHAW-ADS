# %%
import requests
from bs4 import BeautifulSoup
# !pip install lxml 
# wie html-parser, aber schneller

#setting working directory to current one
import os
os.chdir(r'C:\Users\benip\OneDrive\ZHAW\2 Term\Di, 12.50-16.45 (ADS) Applied Data Science\Projekt ADS FS 2022')
# r=raw - weil wir keine "Underscores" im Directory-Namen haben
cwd = os.getcwd()
print(cwd)
# Out:
# ...
# C:\Users\benip\OneDrive\ZHAW\2 Term\Di, 12.50-16.45 (ADS) Applied Data Science\Projekt ADS FS 2022

# %%
# Ordner kreieren, falls nicht vorhanden für Sneakers
dir = os.path.join(r'C:\Users\benip\OneDrive\ZHAW\2 Term\Di, 12.50-16.45 (ADS) Applied Data Science\Projekt ADS FS 2022','sneakers')
if not os.path.exists(dir):
    os.mkdir(dir)
    

# liste initialisieren
sneakers = []
r=0

# %%
# teile der Funktion
r = requests.get(f"https://www.koala.ch/en/shoes/sneakers.html?p=")
print(r)
# Out:
# <Response [200]>

# %%
h = r.content
print(h)
# Out:
# b'<!doctype html><html lang="en"><head prefix="og: http://ogp.me/ns# category: http://ogp.me/ns/category#"><meta charset="utf-8"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.eu01.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={licenseKey:"NRJS-b0b9f61717b576f0eca",applicationID:"311938283"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(){}function i(t,e,n,r){return function(){return s.recordSupportability("API/"+e+"/called"),o(t+e,[u.now()].concat(c(arguments)),n?null:this,r),n?void 0:this}}var o=t("handle"),a=t(9),c=t(10),f=t("ee").get("tracer"),u=t("loader"),s=t(4),d=NREUM;"undefined"==typeof window.newrelic&&(newrelic=d);var p=["setPageViewName","
# ...

# %%
soup=BeautifulSoup(h, 'lxml') 
print(soup.prettify())
# Text ist nicht nach HTML Tags gegliedert...? in bsp war anders - evlt Webseitenaufbau der Grund?
# mit Prettify Funktion ein Müh besser
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head prefix="og: http://ogp.me/ns# category: http://ogp.me/ns/category#">
#   <meta charset="utf-8"/>
#   <script type="text/javascript">
# ...

# %%
# printen der image Tags
imTags=soup.find_all('img',{'class':'product-image-photo'})
print(imTags[0])
# Out:
# <img alt="Chuck Taylor All Star Slip " class="product-image-photo" height="300" loading="lazy" src="https://www.koala.ch/en/media/catalog/product/cache/9beb09f1fe51406f32e0de1d12537581/0/7/0720275-1.jpg" width="240"/>

# %%
# single one - src Tag entscheidend...
src = imTags[0:0]['src']
print(src)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # single one - src Tag entscheidend...
# ----> 2 src = imTags[0:0]['src']
#       3 print(src)
#
# NameError: name 'imTags' is not defined

# %%
# adden einen url (mit itr+1,  weil wir mehrere Seiten wollen). Definieren nicht extra function.
# src ist HTML-Tag für Bilder-Links
# f vor String ist nötig, weil sonst nur eine Seite (f = behält Sematik bei mehr Zeilen und und...  ??)

for itr in range(100):
    try:
        url = f"https://www.koala.ch/en/shoes/sneakers.html?p={itr+1}"
        r = requests.get(url)
        h = r.content
        soup = BeautifulSoup(h, 'lxml')
        imTags=soup.find_all('img',{'class':'product-image-photo'})
        
        for i in imTags:
            sneakers.append(i['src'])
    except:
        pass
    # break funktioniert aus irgend einem grund nicht, deshalb pass

# %% [markdown]
# ## Liste speichern und Bilder in Ordner

# %%
sneakers = list(dict.fromkeys(sneakers))
try:
    sneakers2=sneakers[:1000]
except:
    sneakers2=sneakers
for i,v in enumerate(sneakers2):
    with open('sneakers/'+str(i)+'.jpg','wb') as f:
        im=requests.get(v)
        f.write(im.content)

# %% [markdown]
# ## Vorgang für Ballerinas

# %%
# Ordner kreieren, falls nicht vorhanden für Sneakers
dir = os.path.join(r'C:\Users\benip\OneDrive\ZHAW\2 Term\Di, 12.50-16.45 (ADS) Applied Data Science\Projekt ADS FS 2022','ballerinas')
if not os.path.exists(dir):
    os.mkdir(dir)
    

# liste initialisieren
ballerinas = []
r=0

# %%
# adden einen url (mit itr+1,  weil wir mehrere Seiten wollen). Definieren nicht extra function.
# src ist HTML-Tag für Bilder-Links
# f vor String ist nötig, weil sonst nur eine Seite (f = xxxxxx ??)

for itr in range(100):
    try:
        url = f"https://www.koala.ch/en/shoes/ballerinas.html?p={itr+1}"
        r = requests.get(url)
        h = r.content
        soup = BeautifulSoup(h, 'lxml')
        imTags=soup.find_all('img',{'class':'product-image-photo'})
        
        for i in imTags:
            ballerinas.append(i['src'])
    except:
        pass
    # break funktioniert aus irgend einem grund nicht, deshalb pass

# %%
# allfällige Duplikate aus der Liste entfernen
ballerinas = list(set(ballerinas))

    
# öffne Ballerinas + string hinter image mit Nummer, bspw. 1 + 
# wb = write and binary --> must be used when writing non-text files like images
for i,v in enumerate(ballerinas):
    with open('ballerinas/'+str(i)+'.jpg','wb') as f:
        im=requests.get(v)
        f.write(im.content)

# %%
#optional?
try:
    ballerinas2=ballerinas[:1000]
except:
    ballerinas=ballerinas
